# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests numpy pandas
# Out:
# Collecting openmeteo-requests
#   Downloading openmeteo_requests-1.7.5-py3-none-any.whl.metadata (11 kB)
# Collecting niquests>=3.15.2 (from openmeteo-requests)
#   Downloading niquests-3.18.2-py3-none-any.whl.metadata (15 kB)
# Collecting openmeteo-sdk>=1.22.0 (from openmeteo-requests)
#   Downloading openmeteo_sdk-1.26.0-py3-none-any.whl.metadata (935 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from niquests>=3.15.2->openmeteo-requests) (3.3.2)
# Collecting urllib3-future<3,>=2.13.903 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading urllib3_future-2.17.903-py3-none-any.whl.metadata (16 kB)
# Collecting wassima<3,>=1.0.1 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading wassima-2.0.5-py3-none-any.whl.metadata (3.7 kB)
# Collecting flatbuffers==25.9.23 (from openmeteo-sdk>=1.22.0->openmeteo-requests)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: h11<1.0.0,>=0.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests) (0.14.0)
# Collecting jh2<6.0.0,>=5.0.3 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading jh2-5.0.10-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.0 kB)
# Collecting qh3<2.0.0,>=1.5.4 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading qh3-1.7.0-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (5.0 kB)
# Downloading openmeteo_requests-1.7.5-py3-none-any.whl (7.1 kB)
# Downloading niquests-3.18.2-py3-none-any.whl (207 kB)
# Downloading openmeteo_sdk-1.26.0-py3-none-any.whl (19 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading urllib3_future-2.17.903-py3-none-any.whl (710 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.0/711.0 kB 9.5 MB/s eta 0:00:00
# Downloading wassima-2.0.5-py3-none-any.whl (138 kB)
# Downloading jh2-5.0.10-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (622 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 8.4 MB/s eta 0:00:00
# Downloading qh3-1.7.0-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 23.6 MB/s eta 0:00:00
# Installing collected packages: flatbuffers, wassima, qh3, openmeteo-sdk, jh2, urllib3-future, niquests, openmeteo-requests
# Successfully installed flatbuffers-25.9.23 jh2-5.0.10 niquests-3.18.2 openmeteo-requests-1.7.5 openmeteo-sdk-1.26.0 qh3-1.7.0 urllib3-future-2.17.903 wassima-2.0.5
# Collecting requests-cache
#   Downloading requests_cache-1.3.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting retry-requests
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: attrs>=21.2 in /opt/anaconda3/lib/python3.12/site-packages (from requests-cache) (25.3.0)
# Collecting cattrs>=22.2 (from requests-cache)
#   Downloading cattrs-26.1.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests-cache) (3.10.0)
# Requirement already satisfied: requests>=2.22 in /opt/anaconda3/lib/python3.12/site-packages (from requests-cache) (2.31.0)
# Collecting url-normalize>=2.0 (from requests-cache)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests-cache) (1.26.20)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Collecting attrs>=21.2 (from requests-cache)
#   Downloading attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from cattrs>=22.2->requests-cache) (4.15.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.22->requests-cache) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.22->requests-cache) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.22->requests-cache) (2024.8.30)
# Downloading requests_cache-1.3.1-py3-none-any.whl (70 kB)
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Downloading cattrs-26.1.0-py3-none-any.whl (73 kB)
# Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, attrs, retry-requests, cattrs, requests-cache
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.12.3 requires botocore<1.34.70,>=1.34.41, but you have botocore 1.40.35 which is incompatible.
# label-studio 1.20.0 requires openai<2.0.0,>=1.10.0, but you have openai 1.7.1 which is incompatible.
# label-studio 1.20.0 requires pydantic>=2.9.2, but you have pydantic 2.5.3 which is incompatible.
# label-studio 1.20.0 requires requests<2.33.0,>=2.32.3, but you have requests 2.31.0 which is incompatible.
# Successfully installed attrs-26.1.0 cattrs-26.1.0 requests-cache-1.3.1 retry-requests-2.0.0 url-normalize-2.2.1

# %%
import numpy as np
import pandas as pd
import requests
import openmeteo_requests
import requests_cache
from retry_requests import retry

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 47.5788221,
	"longitude": -122.4112033,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "is_day"],
	"timezone": "America/Los_Angeles",
	"past_days": 2,
	"wind_speed_unit": "mph",
	"temperature_unit": "fahrenheit",
	"precipitation_unit": "inch",
	"forecast_hours": 12,
	"past_hours": 6,
}
responses = openmeteo.weather_api(url, params = params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone: {response.Timezone()}{response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_is_day = hourly.Variables(7).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time() + response.UtcOffsetSeconds(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd() + response.UtcOffsetSeconds(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["is_day"] = hourly_is_day

hourly_dataframe = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", hourly_dataframe)
# Out:
# Coordinates: 47.555702209472656°N -122.38996887207031°E
# Elevation: 0.0 m asl
# Timezone: b'America/Los_Angeles'b'GMT-7'
# Timezone difference to GMT+0: -25200s
#
# Hourly data
#                          date  temperature_2m  relative_humidity_2m  \
# 0  2026-03-23 10:00:00+00:00       42.460701                  89.0
# 1  2026-03-23 11:00:00+00:00       44.530701                  86.0
# 2  2026-03-23 12:00:00+00:00       45.790699                  80.0
# 3  2026-03-23 13:00:00+00:00       45.970699                  69.0
# 4  2026-03-23 14:00:00+00:00       46.600700                  70.0
# 5  2026-03-23 15:00:00+00:00       46.870701                  70.0
# 6  2026-03-23 16:00:00+00:00       47.050697                  70.0
# 7  2026-03-23 17:00:00+00:00       47.320702                  75.0
# 8  2026-03-23 18:00:00+00:00       46.780701                  78.0
# 9  2026-03-23 19:00:00+00:00       45.070702                  81.0
# 10 2026-03-23 20:00:00+00:00       43.810699                  84.0
# 11 2026-03-23 21:00:00+00:00       43.450699                  86.0
# 12 2026-03-23 22:00:00+00:00       42.910698                  87.0
# 13 2026-03-23 23:00:00+00:00       42.640701                  87.0
# 14 2026-03-24 00:00:00+00:00       42.730701                  87.0
# 15 2026-03-24 01:00:00+00:00       42.820702                  85.0
# 16 2026-03-24 02:00:00+00:00       42.730701                  80.0
# 17 2026-03-24 03:00:00+00:00       43.000702                  81.0
#
#     dew_point_2m  apparent_temperature  precipitation_probability  \
# 0      39.448612             38.002071                        0.0
# 1      40.604141             40.181831                        0.0
# 2      39.973305             41.306686                        0.0
# 3      36.371391             39.661907                        0.0
# 4      37.340477             40.941559                        0.0
# 5      37.599529             41.543327                        1.0
# 6      37.772224             41.661430                        2.0
# 7      39.798298             42.689320                        4.0
# 8      40.284515             42.456043                        4.0
# 9      39.590637             40.490860                        3.0
# 10     39.292133             39.451458                        2.0
# 11     39.542885             39.134197                        2.0
# 12     39.308662             38.768642                        3.0
# 13     39.042984             39.193897                        3.0
# 14     39.131542             39.559486                        0.0
# 15     38.624428             38.862289                        0.0
# 16     36.991428             37.775486                        0.0
# 17     37.570572             38.139553                        8.0
#
#     precipitation      rain  is_day
# 0        0.000000  0.000000     1.0
# 1        0.000000  0.000000     1.0
# 2        0.000000  0.000000     1.0
# 3        0.000000  0.000000     1.0
# 4        0.000000  0.000000     1.0
# 5        0.000000  0.000000     1.0
# 6        0.000000  0.000000     1.0
# 7        0.000000  0.000000     1.0
# 8        0.000000  0.000000     1.0
# 9        0.000000  0.000000     1.0
# 10       0.000000  0.000000     0.0
# 11       0.000000  0.000000     0.0
# 12       0.000000  0.000000     0.0
# 13       0.000000  0.000000     0.0
# 14       0.000000  0.000000     0.0
# 15       0.000000  0.000000     0.0
# 16       0.003937  0.003937     0.0
# 17       0.047244  0.047244     0.0
